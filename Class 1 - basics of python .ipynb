# %% [markdown]
# ### This is the practice of python - 31/5/2024

# %%
print("your name")
# Out:
# your name

# %%
print("$"*19)
# Out:
# $$$$$$$$$$$$$$$$$$$

# %%
print("#"*100)
# Out:
# ####################################################################################################

# %%
price_oranges=10
price_apples=20
total_price=price_oranges+price_apples
print(total_price)
# Out:
# 30

# %%
price=4.90
print(price)
# Out:
# 4.9

# %%
flag=True
print(flag)
# Out:
# True

# %%
name=input("what is your name ? ")
print(name)
# Out:
# what is your name ? arya
# arya

# %%
name=input("what is your name ? ")
print("Hi! I am "+name)
# Out:
# what is your name ? arya
# Hi! I am arya

# %% [markdown]
# #### Exercise

# %% [markdown]
# ##### write a code 'What is your name' and 'which is your favourite subject' then write - Arya likes biology

# %%
name=input("What is your name ?")
Subject=input("which is your favourite suject ?")
print(name+ " likes " +Subject)
# Out:
# What is your name ?Arya
# which is your favourite suject ?biology
# Arya likes biology

# %% [markdown]
# ##### Write a code that you ask the year of birth from the user and print his/her age.

# %%
name=input("What is your name? ")
YOB=input("Your year of birth? ")
age=2024-int(YOB)
print(name+ " age is" ,age)
# Out:
# What is your name? Arya
# Your year of birth? 2001
# Arya age is 23
